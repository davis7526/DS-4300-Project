# %%
import pandas as pd
import numpy as np
import json
import ast

# %%
df = pd.read_json(r'\Users\Davis Goren\Desktop\DS 4300\yelp_academic_dataset_business.json', lines=True)
df = df[df['categories'].str.contains('Restaurants', na=False)].dropna()

# %%
df
# Out:
#                    business_id                     name  \
# 0       6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom
# 1       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX
# 5       D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food
# 12      HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs
# 13      ufCxltuh56FF4-ZFZ6cVhg           Sister Honey's
# ...                        ...                      ...
# 160572  r5Uag1JqYjr2nbxQCVqm8A    Saigon Noodle & Grill
# 160573  Zl6SUy6x9jqjRu2HbtEO6A     Split Dine and Drink
# 160574  Q78fYV6B6P6GmX07YVgi4g  Maudieâ€™s Hill Country
# 160575  uXdQkuEtvLAzfc3MsO-sTQ     Mama's Cocina Latina
# 160584  ngmLL5Y5OT-bYHKU0kKrYA              Zora Grille
#
#                       address               city state postal_code   latitude  \
# 0                921 Pearl St            Boulder    CO       80302  40.017544
# 1         7000 NE Airport Way           Portland    OR       97218  45.588906
# ...

# %%
df = df.drop(columns = ['latitude', 'longitude', 'business_id']).reset_index(drop=True)

# %%
df['attributes'] = df['attributes'].apply(lambda x: attribute_filter(x))
df['hours'] = df['hours'].apply(lambda x: hours_filter(x))
df['categories'] = df['categories'].apply(lambda x: categories_conversion(x))

# %%
df['hours'] = df['hours'].apply(lambda x: hours_filter(x))

# %%
#filters out all attribute values with False
def attribute_filter(attributes):
    for k in list(attributes):
        if attributes[k] == 'False' or attributes[k] =='None' or attributes[k] == "u'none'":
             attributes.pop(k, None)
        elif attributes[k][0] == '{':
             attributes.pop(k, None)
    return attributes

# %%
def hours_filter(hours):
    for k in list(hours):
        if hours[k] == '0:0-0:0':
            hours.pop(k, None)
    if bool(hours):
        return hours
    else:
        return

# %%
def categories_conversion(categories):
    categories = categories.replace(" ", "").split(",")
    return categories

# %%
df = df.dropna().reset_index(drop=True)

# %%
df
# Out:
#                           name                address               city  \
# 0          Oskar Blues Taproom           921 Pearl St            Boulder
# 1      Flying Elephants at PDX    7000 NE Airport Way           Portland
# 2          Bob Likes Thai Food           3755 Main St          Vancouver
# 3          Mr G's Pizza & Subs          474 Lowell St            Peabody
# 4               Sister Honey's      247 E Michigan St            Orlando
# ...                        ...                    ...                ...
# 41673            The Jury Room         39 Cottage Ave             Quincy
# 41674    Saigon Noodle & Grill        101 N Bumby Ave            Orlando
# 41675     Split Dine and Drink  7335 SW Bridgeport Rd             Tigard
# 41676  Maudieâ€™s Hill Country       12506 Shops Pkwy           Bee Cave
# 41677              Zora Grille    1370 E Altamonte Dr  Altamonte Springs
#
#       state postal_code  stars  review_count  is_open  \
# ...

# %%
df['attributes'][3]
# Out:
# {'RestaurantsGoodForGroups': 'True',
#  'HasTV': 'True',
#  'GoodForKids': 'True',
#  'RestaurantsTakeOut': 'True',
#  'RestaurantsPriceRange2': '2',
#  'BikeParking': 'True',
#  'RestaurantsAttire': "u'casual'",
#  'RestaurantsDelivery': 'True',
#  'OutdoorSeating': 'True',
#  'DogsAllowed': 'True',
#  'NoiseLevel': "'average'",
#  'BusinessAcceptsCreditCards': 'True',
#  'Caters': 'True',
#  'WheelchairAccessible': 'True',
#  'WiFi': "u'free'"}

# %%
cleaned_dataset = df.to_json(r'\Users\Davis Goren\Desktop\DS 4300\restaurant_data_final_v2.json', orient='records')

# %%
testing_dataset = df[:300].to_json(r'\Users\Davis Goren\Desktop\DS 4300\restaurant_data_final_test_v2.json', orient='records')

# %%
df[:300]
# Out:
#                                  name                       address  \
# 0                 Oskar Blues Taproom                  921 Pearl St
# 1             Flying Elephants at PDX           7000 NE Airport Way
# 2                 Bob Likes Thai Food                  3755 Main St
# 3                 Mr G's Pizza & Subs                 474 Lowell St
# 4                      Sister Honey's             247 E Michigan St
# ..                                ...                           ...
# 295                         Carroll's                    21 Main St
# 296  Gusto Italian Kitchen & Wine Bar                4800 Burnet Rd
# 297       INKAâ€™S Peruvian Resturant         184 Broadway, Unit 10
# 298        Ryan's Village Pizza & Pub              405 Delannoy Ave
# 299            Fanoos Persian Cuisine  6125 Roswell Rd NE, Ste 104B
#
#           city state postal_code  stars  review_count  is_open  \
# 0      Boulder    CO       80302    4.0            86        1
# ...

# %%
type(df['categories'][0])
# Out:
# list

# %%
df
# Out:
#                           name                address               city  \
# 0          Oskar Blues Taproom           921 Pearl St            Boulder
# 1      Flying Elephants at PDX    7000 NE Airport Way           Portland
# 2          Bob Likes Thai Food           3755 Main St          Vancouver
# 3          Mr G's Pizza & Subs          474 Lowell St            Peabody
# 4               Sister Honey's      247 E Michigan St            Orlando
# ...                        ...                    ...                ...
# 41673            The Jury Room         39 Cottage Ave             Quincy
# 41674    Saigon Noodle & Grill        101 N Bumby Ave            Orlando
# 41675     Split Dine and Drink  7335 SW Bridgeport Rd             Tigard
# 41676  Maudieâ€™s Hill Country       12506 Shops Pkwy           Bee Cave
# 41677              Zora Grille    1370 E Altamonte Dr  Altamonte Springs
#
#       state postal_code  stars  review_count  is_open  \
# ...
